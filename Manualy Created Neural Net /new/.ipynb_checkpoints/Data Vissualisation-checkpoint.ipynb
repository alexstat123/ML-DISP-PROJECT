# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

# %%
data = pd.read_csv('../input/patches.csv')
data.sample(n=5)
# Out:
#                p       p.1       p.2       p.3  class
# 106055  0.293124  0.297045  0.290021  0.299003      0
# 178776  0.426076  0.466155  0.468402  0.476253      0
# 52962   0.543680  0.558273  0.538351  0.552096      0
# 332746  0.028016  0.027451  0.024095  0.023529      0
# 199741  0.000000  0.000000  0.000000  0.000000      0

# %%
sns_plot = sns.pairplot( data=data, vars=('p','p.1','p.2','p.3'), hue='class' )

# %%
sns_plot.savefig("data_visualisation.png")
